# %%
# Load libraries for basic computing 
import numpy as np
import pandas as pd
from datetime import datetime
import matplotlib.dates as mdates

# Load libraries for regression
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# Load libraries for visualization
import seaborn as sb
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("isedol_total_cleanse.csv")
#print(df)
df.head(5)
# Out:
#      user  index_months  year  month  date  weekday date_formatting  \
# 0  vo_ine            15  2022      3    14        1       3/14/2022
# 1  vo_ine            15  2022      3    13        7       3/13/2022
# 2  vo_ine            15  2022      3    12        6       3/12/2022
# 3  vo_ine            15  2022      3    11        5       3/11/2022
# 4  vo_ine            15  2022      3    10        4       3/10/2022
#
#                                           stream_url  length_minute  \
# 0  https://sullygnome.com/channel/vo_ine/stream/4...            178
# 1  https://sullygnome.com/channel/vo_ine/stream/4...            105
# 2  https://sullygnome.com/channel/vo_ine/stream/4...            354
# 3  https://sullygnome.com/channel/vo_ine/stream/4...            396
# 4  https://sullygnome.com/channel/vo_ine/stream/4...            508
#
#    watchtime_hrs  avg_viewers  peak_viewers  new_followers  followers_hourly  \
# 0        1770032         9944         15773            512               157
# 1        1234065        11753         15257            306               153
# 2        3208656         9064         12671            627               100
# 3        3303432         8342         14061           1123               166
# 4        3025140         5955         10314            805                92
#
#     views  views_hourly      Cattegory  co_stream  event
# 0   70685         21749  Just Chatting        NaN    NaN
# 1   30565         15282  Just Chatting        NaN    NaN
# 2   80187         12829  Just Chatting        NaN    NaN
# 3  136579         20233  Just Chatting        NaN    1.0
# 4  109850         12554  Just Chatting        NaN    NaN

# %%
# 날짜 관련 변수
# year
# month
# date
# Index_month : 월별 순서
# date_formatting : 정식규격 날짜(MM/DD/YYYY)
# weekday : 요일

# 기타 등등
# stream_url : 스트리밍 주소
# Cattegory : 방송 카테고리
# co_stream : 합방 여부
# event : 이벤트 여부

# 시청 정보
# length_minute : 분길이
# watchtime_hrs: 분단위
# avg_viewer : 평균 시청자 수
# peak_viewer : 최고점 시청자 수
# new_followers : 새 팔로워
# followers_hourly : 시간당 새 팔로워 수
# views : 시청수
# views_hourly : 시간당 시청수

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 977 entries, 0 to 976
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   user              977 non-null    object
#  1   index_months      977 non-null    int64
#  2   year              977 non-null    int64
#  3   month             977 non-null    int64
#  4   date              977 non-null    int64
#  5   weekday           977 non-null    int64
#  6   date_formatting   977 non-null    object
#  7   stream_url        977 non-null    object
#  8   length_minute     977 non-null    int64
#  9   watchtime_hrs     977 non-null    int64
#  10  avg_viewers       977 non-null    int64
#  11  peak_viewers      977 non-null    int64
#  12  new_followers     977 non-null    int64
#  13  followers_hourly  977 non-null    int64
#  14  views             977 non-null    int64
#  15  views_hourly      977 non-null    int64
#  16  Cattegory         977 non-null    object
#  17  co_stream         67 non-null     float64
#  18  event             20 non-null     float64
# dtypes: float64(2), int64(13), object(4)
# memory usage: 145.1+ KB

# %%
df.describe()
df.describe(include=['O'])
# Out:
#               user date_formatting  \
# count          977             977
# unique           7             189
# top     woowakgood      12/17/2021
# freq           174              13
#
#                                                stream_url      Cattegory
# count                                                 977            977
# unique                                                977             20
# top     https://sullygnome.com/channel/viichan6/stream...  Just Chatting
# freq                                                    1            909

# %%
#plt.boxplot(df.views)
#plt.boxplot(df.avg_viewers)

plt.boxplot([df.length_minute, df.watchtime_hrs, df.avg_viewers, df.peak_viewers, df.new_followers, df.views, df.views_hourly])
plt.show()

# %%
plt.boxplot([df.watchtime_hrs, df.views])
plt.show()

# %%
#Correlation 한눈에 편하게 보기(근데 레이아웃 많이 안 좋음)
s = corr_df.unstack()
s
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-6ea149eb3769> in <module>
#       1 #Correlation 한눈에 편하게 보기(근데 레이아웃 많이 안 좋음)
# ----> 2 s = corr_df.unstack()
#       3 s
#
# NameError: name 'corr_df' is not defined

# %%
plt.rcParams["figure.figsize"] = (15,15)
sb.heatmap(df.corr(),
           annot = True, #실제 값 화면에 나타내기
           cmap = 'Greens', #색상
           vmin = -1, vmax=1 , #컬러차트 영역 -1 ~ +1
          )
# Out:
# <AxesSubplot:>

# %%
# 개별 User의 필터링 조건(ex. Ine)
is_ine = df['user'] == 'vo_ine'
ine = df[is_ine]

is_lilpa = df['user'] == 'lilpa'
lilpa = df[is_lilpa]

is_vii = df['user'] == 'viichan'
viichan = df[is_vii]

is_jing = df['user'] == 'jingburger'
jingburger = df[is_jing]

is_gsg = df['user'] == 'gosegu'
gosegu = df[is_gsg]

is_jrr = df['user'] == 'jururu'
jururu = df[is_jrr]

is_woo = df['user'] == 'woowakgood'
woowakgood = df[is_woo]

# %%
# pyplot 예시 (시간대별 분석) 그래프 예시
plt.plot(pd.to_datetime(df[is_ine]['date_formatting']), df[is_ine].watchtime_hrs)
plt.title('Watchtime_hrs tendency - vo_ine')
# Out:
# Text(0.5, 1.0, 'Watchtime_hrs tendency - vo_ine')

# %%
plt.figure(figsize=(20,10))
plt.title('Overall Tendency toward time series - ISEDOL',fontsize=40)
plt.plot(pd.to_datetime(df[is_ine]['date_formatting']), df[is_ine].watchtime_hrs, color="violet")
plt.plot(pd.to_datetime(df[is_lilpa]['date_formatting']), df[is_lilpa].watchtime_hrs, color="blue")
plt.plot(pd.to_datetime(df[is_vii]['date_formatting']), df[is_vii].watchtime_hrs, color="greenyellow")
plt.plot(pd.to_datetime(df[is_jing]['date_formatting']), df[is_jing].watchtime_hrs, color="gold")
plt.plot(pd.to_datetime(df[is_gsg]['date_formatting']), df[is_gsg].watchtime_hrs, color="cyan")
plt.plot(pd.to_datetime(df[is_jrr]['date_formatting']), df[is_jrr].watchtime_hrs, color="purple")
plt.plot(pd.to_datetime(df[is_woo]['date_formatting']), df[is_woo].watchtime_hrs, color="gold")

# %%
# 개별비교분석 그래프
f, axes = plt.subplots(4, 2)
f.set_size_inches((20, 15))
plt.subplots_adjust(wspace = 0.3, hspace = 0.3)
plt.suptitle('Tendency line for watchtime_hrs',fontsize=40)

axes[0, 0].plot(pd.to_datetime(df[is_ine]['date_formatting']), df[is_ine].watchtime_hrs, color="violet")
axes[0, 0].set_title("Ine")

axes[0, 1].plot(pd.to_datetime(df[is_lilpa]['date_formatting']), df[is_lilpa].watchtime_hrs, color="blue")
axes[0, 1].set_title('Lilpa')

axes[1, 0].plot(pd.to_datetime(df[is_vii]['date_formatting']), df[is_vii].watchtime_hrs, color="greenyellow")
axes[1, 0].set_title('Viichan')

axes[1, 1].plot(pd.to_datetime(df[is_jing]['date_formatting']), df[is_jing].watchtime_hrs, color="gold")
axes[1, 1].set_title('WJingburger')

axes[2, 0].plot(pd.to_datetime(df[is_gsg]['date_formatting']), df[is_gsg].watchtime_hrs, color="cyan")
axes[2, 0].set_title('Gosegu')

axes[2, 1].plot(pd.to_datetime(df[is_jrr]['date_formatting']), df[is_jrr].watchtime_hrs, color="purple")
axes[2, 1].set_title('Jururu')

axes[3, 0].plot(pd.to_datetime(df[is_woo]['date_formatting']), df[is_woo].watchtime_hrs, color="gold")
axes[3, 0].set_title('Woowakgood')
# Out:
# Text(0.5, 1.0, 'Woowakgood')

# %%
#df[df['country'] == '한국']
df_bf = df[df['index_months'] == 9]
df_bf[['user', 'watchtime_hrs']].groupby(['user'], as_index=True).mean().plot.bar()
# Out:
# <AxesSubplot:xlabel='user'>

# %%
df_af = df[df['index_months'] == 15]
df_af[['user', 'watchtime_hrs']].groupby(['user'], as_index=True).mean().plot.bar()
# Out:
# <AxesSubplot:xlabel='user'>

# %%
df_bf[df['user'] == 'gosegu']
# Out:
# <ipython-input-56-62423541cd40>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_bf[df['user'] == 'gosegu']
#        user  index_months  year  month  date  weekday date_formatting  \
# 547  gosegu            15  2022      3    14        1       3/14/2022
# 548  gosegu            15  2022      3    12        6       3/12/2022
# 549  gosegu            15  2022      3    11        5       3/11/2022
# 550  gosegu            15  2022      3    10        4       3/10/2022
# 551  gosegu            15  2022      3     9        3        3/9/2022
# 552  gosegu            15  2022      3     8        2        3/8/2022
# 553  gosegu            15  2022      3     7        1        3/7/2022
# 554  gosegu            15  2022      3     5        6        3/5/2022
# 555  gosegu            15  2022      3     5        6        3/5/2022
# 556  gosegu            15  2022      3     2        3        3/2/2022
# 557  gosegu            15  2022      3     1        2        3/1/2022
#
#                                             stream_url  length_minute  \
# 547  https://sullygnome.com/channel/gosegugosegu/st...            454
# 548  https://sullygnome.com/channel/gosegugosegu/st...            457
# 549  https://sullygnome.com/channel/gosegugosegu/st...            343
# 550  https://sullygnome.com/channel/gosegugosegu/st...            266
# 551  https://sullygnome.com/channel/gosegugosegu/st...            203
# 552  https://sullygnome.com/channel/gosegugosegu/st...            567
# 553  https://sullygnome.com/channel/gosegugosegu/st...            362
# 554  https://sullygnome.com/channel/gosegugosegu/st...            629
# 555  https://sullygnome.com/channel/gosegugosegu/st...            141
# 556  https://sullygnome.com/channel/gosegugosegu/st...            640
# 557  https://sullygnome.com/channel/gosegugosegu/st...            474
#
#      watchtime_hrs  avg_viewers  peak_viewers  new_followers  \
# 547        3219768         7092         11371            814
# 548        3214538         7034          9685            681
# 549        1636796         4772          7712            980
# 550         958132         3602          8647            556
# 551        1057224         5208          6708            322
# 552        3683799         6497          9807            843
# 553        2448930         6765          9278            579
# 554        2649977         4213          9392            678
# 555        1021686         7246          8933            379
# 556        2191360         3424          4953            504
# 557        2870070         6055         12792            794
#
#      followers_hourly  views  views_hourly      Cattegory  co_stream  event
# 547               105  79823         10299  Just Chatting        NaN    NaN
# 548                85  76622          9577  Just Chatting        NaN    NaN
# 549               163  96898         16149  Just Chatting        NaN    1.0
# 550               117  74659         15717  Just Chatting        NaN    NaN
# 551                85  31628          8434  Just Chatting        NaN    NaN
# 552                86  53810          5518  Just Chatting        NaN    NaN
# 553                92  44464          7114  Just Chatting        NaN    NaN
# 554                63  67270          6257  Just Chatting        NaN    NaN
# 555               151  17277          6910  Just Chatting        NaN    NaN
# 556                45  40381          3671  Just Chatting        NaN    NaN
# 557                96  81150          9836  Just Chatting        NaN    NaN

# %%
resultset = np.array([[sum(df_bf[df['user'] == 'gosegu'].watchtime_hrs),
                      sum(df_bf[df['user'] == 'jingburger'].watchtime_hrs),
                      sum(df_bf[df['user'] == 'jururu'].watchtime_hrs),
                      sum(df_bf[df['user'] == 'lilpa'].watchtime_hrs),
                      sum(df_bf[df['user'] == 'viichan'].watchtime_hrs),
                      sum(df_bf[df['user'] == 'vo_ine'].watchtime_hrs),
                      sum(df_bf[df['user'] == 'woowakgood'].watchtime_hrs)],
                     [sum(df_af[df['user'] == 'gosegu'].watchtime_hrs),
                      sum(df_af[df['user'] == 'jingburger'].watchtime_hrs),
                      sum(df_af[df['user'] == 'jururu'].watchtime_hrs),
                      sum(df_af[df['user'] == 'lilpa'].watchtime_hrs),
                      sum(df_af[df['user'] == 'viichan'].watchtime_hrs),
                      sum(df_af[df['user'] == 'vo_ine'].watchtime_hrs),
                      sum(df_af[df['user'] == 'woowakgood'].watchtime_hrs)]])

resultset
# Out:
# <ipython-input-82-bf20b60bfe89>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   resultset = np.array([[sum(df_bf[df['user'] == 'gosegu'].watchtime_hrs),
# <ipython-input-82-bf20b60bfe89>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   sum(df_bf[df['user'] == 'jingburger'].watchtime_hrs),
# <ipython-input-82-bf20b60bfe89>:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   sum(df_bf[df['user'] == 'jururu'].watchtime_hrs),
# <ipython-input-82-bf20b60bfe89>:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   sum(df_bf[df['user'] == 'lilpa'].watchtime_hrs),
# <ipython-input-82-bf20b60bfe89>:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   sum(df_bf[df['user'] == 'viichan'].watchtime_hrs),
# <ipython-input-82-bf20b60bfe89>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   sum(df_bf[df['user'] == 'vo_ine'].watchtime_hrs),
# <ipython-input-82-bf20b60bfe89>:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   sum(df_bf[df['user'] == 'woowakgood'].watchtime_hrs)],
# <ipython-input-82-bf20b60bfe89>:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   [sum(df_af[df['user'] == 'gosegu'].watchtime_hrs),
# <ipython-input-82-bf20b60bfe89>:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   sum(df_af[df['user'] == 'jingburger'].watchtime_hrs),
# <ipython-input-82-bf20b60bfe89>:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   sum(df_af[df['user'] == 'jururu'].watchtime_hrs),
# <ipython-input-82-bf20b60bfe89>:11: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   sum(df_af[df['user'] == 'lilpa'].watchtime_hrs),
# <ipython-input-82-bf20b60bfe89>:12: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   sum(df_af[df['user'] == 'viichan'].watchtime_hrs),
# <ipython-input-82-bf20b60bfe89>:13: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   sum(df_af[df['user'] == 'vo_ine'].watchtime_hrs),
# <ipython-input-82-bf20b60bfe89>:14: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   sum(df_af[df['user'] == 'woowakgood'].watchtime_hrs)]])
# array([[ 12912137,   6975678,   5132579,   6114299,  10137617,   8573704,
#          74479531],
#        [ 24952280,  20005260,  12088393,  18696910,  24265800,  28672685,
#         100082792]])

# %%
X = np.arange(7)

plt.bar(X + 0.00, resultset[0], color='r', width=0.25)
plt.bar(X + 0.25, resultset[1], color='b', width=0.25)
# Out:
# <BarContainer object of 7 artists>
