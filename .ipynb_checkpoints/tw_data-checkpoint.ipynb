# %%
# Load libraries for basic computing 
import numpy as np
import pandas as pd

# Load libraries for regression
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# Load libraries for visualization
import seaborn as sb
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("isedol_total_cleanse.csv")
print(df)
# Out:
#            user  index_months  year  month  date  weekday date_formatting  \
# 0        vo_ine            15  2022      3    14        1       3/14/2022
# 1        vo_ine            15  2022      3    13        7       3/13/2022
# 2        vo_ine            15  2022      3    12        6       3/12/2022
# 3        vo_ine            15  2022      3    11        5       3/11/2022
# 4        vo_ine            15  2022      3    10        4       3/10/2022
# ..          ...           ...   ...    ...   ...      ...             ...
# 972  woowakgood             9  2021      9     8        3        9/8/2021
# 973  woowakgood             9  2021      9     7        2        9/7/2021
# 974  woowakgood             9  2021      9     6        1        9/6/2021
# 975  woowakgood             9  2021      9     5        7        9/5/2021
# 976  woowakgood             9  2021      9     4        6        9/4/2021
#
#                                             stream_url  length_minute  \
# 0    https://sullygnome.com/channel/vo_ine/stream/4...            178
# 1    https://sullygnome.com/channel/vo_ine/stream/4...            105
# 2    https://sullygnome.com/channel/vo_ine/stream/4...            354
# 3    https://sullygnome.com/channel/vo_ine/stream/4...            396
# 4    https://sullygnome.com/channel/vo_ine/stream/4...            508
# ..                                                 ...            ...
# 972  https://sullygnome.com/channel/woowakgood/stre...            416
# 973  https://sullygnome.com/channel/woowakgood/stre...            547
# 974  https://sullygnome.com/channel/woowakgood/stre...            369
# 975  https://sullygnome.com/channel/woowakgood/stre...            490
# 976  https://sullygnome.com/channel/woowakgood/stre...            310
#
#      watchtime_hrs  avg_viewers  peak_viewers  new_followers  \
# 0          1770032         9944         15773            512
# 1          1234065        11753         15257            306
# 2          3208656         9064         12671            627
# 3          3303432         8342         14061           1123
# 4          3025140         5955         10314            805
# ..             ...          ...           ...            ...
# 972        1720160         4135          5360            165
# 973        3004124         5492          9174            351
# 974        2100348         5692          7292            255
# 975        4276720         8728         11772            446
# 976        1639590         5289          6061            255
#
#      followers_hourly   views  views_hourly      Cattegory  co_stream  event
# 0                 157   70685         21749  Just Chatting        NaN    NaN
# 1                 153   30565         15282  Just Chatting        NaN    NaN
# 2                 100   80187         12829  Just Chatting        NaN    NaN
# 3                 166  136579         20233  Just Chatting        NaN    1.0
# 4                  92  109850         12554  Just Chatting        NaN    NaN
# ..                ...     ...           ...            ...        ...    ...
# 972                23   37353          5336         VRChat        NaN    NaN
# 973                37   56158          6071  Just Chatting        NaN    NaN
# 974                40   40796          6527  Just Chatting        NaN    NaN
# 975                54   92600         11224  Just Chatting        1.0    NaN
# 976                48   38905          7410      Minecraft        NaN    NaN
#
# [977 rows x 19 columns]

# %%
# 날짜 관련 변수
# year
# month
# date
# Index_month : 월별 순서
# date_formatting : 정식규격 날짜(MM/DD/YYYY)
# weekday : 요일

# 기타 등등
# stream_url : 스트리밍 주소
# Cattegory : 방송 카테고리
# co_stream : 합방 여부
# event : 이벤트 여부

# 시청 정보
# length_minute : 분길이
# watchtime_hrs: 분단위
# avg_viewer : 평균 시청자 수
# peak_viewer : 최고점 시청자 수
# new_followers : 새 팔로워
# followers_hourly : 시간당 새 팔로워 수
# views : 시청수
# views_hourly : 시간당 시청수
# Out:
#                   index_months  year  month  date  weekday  length_minute  \
# index_months              1.00  0.84  -0.69 -0.14    -0.04          -0.02
# year                      0.84  1.00  -0.97 -0.13    -0.02          -0.02
# month                    -0.69 -0.97   1.00  0.11     0.01           0.01
# date                     -0.14 -0.13   0.11  1.00     0.03          -0.05
# weekday                  -0.04 -0.02   0.01  0.03     1.00           0.11
# length_minute            -0.02 -0.02   0.01 -0.05     0.11           1.00
# watchtime_hrs             0.39  0.38  -0.34  0.01     0.04           0.47
# avg_viewers               0.51  0.49  -0.43  0.03     0.00           0.20
# peak_viewers              0.52  0.50  -0.44  0.01     0.02           0.25
# new_followers             0.45  0.53  -0.51  0.00     0.05           0.43
# followers_hourly          0.47  0.53  -0.50  0.05     0.00          -0.18
# views                     0.50  0.50  -0.46 -0.02     0.09           0.50
# views_hourly              0.63  0.62  -0.55  0.01     0.05           0.05
# co_stream                  NaN   NaN    NaN   NaN      NaN            NaN
# event                      NaN   NaN    NaN   NaN      NaN            NaN
#
#                   watchtime_hrs  avg_viewers  peak_viewers  new_followers  \
# index_months               0.39         0.51          0.52           0.45
# year                       0.38         0.49          0.50           0.53
# month                     -0.34        -0.43         -0.44          -0.51
# date                       0.01         0.03          0.01           0.00
# weekday                    0.04         0.00          0.02           0.05
# length_minute              0.47         0.20          0.25           0.43
# watchtime_hrs              1.00         0.92          0.93           0.47
# avg_viewers                0.92         1.00          0.98           0.42
# peak_viewers               0.93         0.98          1.00           0.47
# new_followers              0.47         0.42          0.47           1.00
# followers_hourly           0.15         0.31          0.33           0.71
# views                      0.91         0.83          0.88           0.65
# views_hourly               0.70         0.82          0.84           0.54
# co_stream                   NaN          NaN           NaN            NaN
# event                       NaN          NaN           NaN            NaN
#
#                   followers_hourly  views  views_hourly  co_stream  event
# index_months                  0.47   0.50          0.63        NaN    NaN
# year                          0.53   0.50          0.62        NaN    NaN
# month                        -0.50  -0.46         -0.55        NaN    NaN
# date                          0.05  -0.02          0.01        NaN    NaN
# weekday                       0.00   0.09          0.05        NaN    NaN
# length_minute                -0.18   0.50          0.05        NaN    NaN
# watchtime_hrs                 0.15   0.91          0.70        NaN    NaN
# avg_viewers                   0.31   0.83          0.82        NaN    NaN
# peak_viewers                  0.33   0.88          0.84        NaN    NaN
# new_followers                 0.71   0.65          0.54        NaN    NaN
# followers_hourly              1.00   0.31          0.58        NaN    NaN
# views                         0.31   1.00          0.82        NaN    NaN
# views_hourly                  0.58   0.82          1.00        NaN    NaN
# co_stream                      NaN    NaN           NaN        NaN    NaN
# event                          NaN    NaN           NaN        NaN    NaN

# %%
#plt.boxplot(df.views)
#plt.boxplot(df.avg_viewers)

plt.boxplot([df.length_minute, df.watchtime_hrs, df.avg_viewers, df.peak_viewers, df.new_followers, df.views, df.views_hourly])
plt.show()

# %%
plt.boxplot([df.watchtime_hrs, df.views])
plt.show()

# %%
#Correlation 한눈에 편하게 보기(근데 레이아웃 많이 안 좋음)
s = corr_df.unstack()
s
# Out:
# index_months  index_months        1.00
#               year                0.84
#               month              -0.69
#               date               -0.14
#               weekday            -0.04
#                                   ...
# event         followers_hourly     NaN
#               views                NaN
#               views_hourly         NaN
#               co_stream            NaN
#               event                NaN
# Length: 225, dtype: float64

# %%
plt.rcParams["figure.figsize"] = (15,15)
sb.heatmap(df.corr(),
           annot = True, #실제 값 화면에 나타내기
           cmap = 'Greens', #색상
           vmin = -1, vmax=1 , #컬러차트 영역 -1 ~ +1
          )
# Out:
# <AxesSubplot:>

# %%
df = df[['date_formatting','watchtime_hrs','avg_viewers','new_followers','views']]
df['lscrap'] = np.log(df['scrap'])
df = df.dropna()
#df = df[df.index!=30]
df = panelDF(df,id='fcode',time='year')
df = df.outer_balance()
df
